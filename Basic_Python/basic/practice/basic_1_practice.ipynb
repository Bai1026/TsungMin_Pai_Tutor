# %% [markdown]
# # Python 新手指南：01 變數、資料型態、語法 - 練習題
#
# **作者：** Tsung-Min Pai
# **單位：** NTUEE
#
# ---
#
# ## 📝 練習說明
#
# 這個練習本包含多個練習題，幫助你熟悉 Python 的基本語法、變數使用和 print() 函式。
#
# **練習方式：**
# 1. 閱讀每個練習題的說明和註解
# 2. 在標記 `# TODO:` 的地方完成程式碼
# 3. 執行程式碼儲存格來檢查結果
# 4. 確保輸出符合預期結果
#
# **提示：** 如果遇到困難，可以參考教學文件或詢問助教！
#
# ---

# %% [markdown]
# ## 練習 1：基本變數宣告與 print()
#
# **目標：** 學會建立變數並使用 print() 輸出

# %%
# 練習 1：基本變數和輸出
# 請建立以下變數並使用 print() 輸出

# TODO: 建立一個名為 'my_name' 的變數，儲存你的名字
my_name = "aa"

# # TODO: 建立一個名為 'my_age' 的變數，儲存你的年齡
# my_age = 

# # TODO: 使用 print() 輸出你的名字


# # TODO: 使用 print() 輸出你的年齡


# # 預期輸出範例：
# # 張小明
# # 20
# Out:
# aa

# %% [markdown]
# ## 練習 2：f-string 格式化
#
# **目標：** 學會使用 f-string 進行字串格式化

# %%
# 練習 2：f-string 格式化
# 使用上面建立的變數，用 f-string 建立更豐富的輸出

# 已給定的變數
school = "台灣大學"
department = "電機工程學系"

# TODO: 使用 f-string 輸出自我介紹，格式如下：
# "我是 [姓名]，今年 [年齡] 歲，就讀於 [學校] [科系]"


# TODO: 計算並輸出你 10 年後的年齡，使用 f-string
# 格式："10 年後我將 [年齡] 歲"


# 預期輸出範例：
# 我是 張小明，今年 20 歲，就讀於 台灣大學 電機工程學系
# 10 年後我將 30 歲

# %% [markdown]
# ## 練習 3：數字格式化
#
# **目標：** 學會在 f-string 中格式化數字

# %%
# 練習 3：數字格式化練習
# 練習使用 f-string 格式化不同類型的數字

# 已給定的變數
pi = 3.14159265359
price = 1250.5
success_rate = 0.873

# TODO: 使用 f-string 輸出圓周率，保留 2 位小數
# 格式："圓周率約為 3.14"


# TODO: 使用 f-string 輸出價格，保留 0 位小數
# 格式："商品價格：1251 元"


# TODO: 使用 f-string 輸出成功率為百分比，保留 1 位小數
# 格式："成功率：87.3%"


# 預期輸出：
# 圓周率約為 3.14
# 商品價格：1251 元
# 成功率：87.3%

# %% [markdown]
# ## 練習 4：print() 進階參數
#
# **目標：** 學會使用 print() 的 sep 和 end 參數

# %%
# 練習 4：print() 進階參數練習
# 學習使用 sep 和 end 參數控制輸出格式

# 已給定的變數
fruits = ["蘋果", "香蕉", "橘子", "葡萄"]

# TODO: 使用 print() 和 sep 參數，將水果用 " | " 分隔輸出
# 預期輸出："蘋果 | 香蕉 | 橘子 | 葡萄"


# TODO: 使用 print() 和 end 參數，輸出載入進度
# 請依序執行以下步驟：
# 1. 輸出 "載入中" (不換行)

# 2. 輸出三個點 "." (每個都不換行)



# 3. 最後輸出 " 完成!" (這個會換行)


# 預期輸出：
# 蘋果 | 香蕉 | 橘子 | 葡萄
# 載入中... 完成!

# %% [markdown]
# ## 練習 5：多行字串與註解
#
# **目標：** 學會使用多行字串和註解

# %%
# 練習 5：多行字串與註解練習

# TODO: 建立一個多行字串變數 'poem'，內容為一首簡短的詩
# 可以是任何你喜歡的詩，至少要有 3 行
poem = """

"""

# TODO: 使用 print() 輸出這首詩


# TODO: 在下面寫一個多行註解，解釋這首詩的含義或為什麼選擇它
"""

"""

# %% [markdown]
# ## 練習 6：表格式輸出
#
# **目標：** 學會建立格式化的表格輸出

# %%
# 練習 6：建立學生成績表
# 學習使用字串格式化建立表格

# 已給定的學生資料
students = [
    {"name": "張小明", "math": 95, "english": 88, "science": 92},
    {"name": "李小華", "math": 87, "english": 94, "science": 89},
    {"name": "王小美", "math": 92, "english": 85, "science": 96}
]

# TODO: 輸出表格標題行，使用適當的欄位寬度
# 格式："姓名      數學  英文  理化"


# TODO: 輸出分隔線


# TODO: 使用迴圈輸出每個學生的成績，保持對齊
for student in students:
    # 在這裡完成格式化輸出
    pass

# 預期輸出：
# 姓名      數學  英文  理化
# ------------------------
# 張小明     95    88    92
# 李小華     87    94    89
# 王小美     92    85    96

# %% [markdown]
# ## 練習 7：進度條製作
#
# **目標：** 學會製作簡單的文字進度條

# %%
# 練習 7：製作進度條
# 學習製作視覺化的進度顯示

# 已給定的變數
total_tasks = 50
completed_tasks = 32
bar_length = 20  # 進度條的長度

# TODO: 計算完成百分比
percentage = 

# TODO: 計算進度條中應該填滿的部分長度
filled_length = 

# TODO: 建立進度條字串
# 使用 "█" 表示已完成，"░" 表示未完成
bar = 

# TODO: 輸出完整的進度資訊
# 格式："進度: |████████████░░░░░░░░| 64.0% (32/50)"


# 預期輸出類似：
# 進度: |████████████░░░░░░░░| 64.0% (32/50)

# %% [markdown]
# ## 練習 8：JSON 格式化輸出
#
# **目標：** 學會使用 json 模組進行格式化輸出

# %%
# 練習 8：JSON 格式化練習
# 學習使用 json.dumps() 美化複雜資料結構的輸出

# TODO: 匯入 json 模組


# 已給定的複雜資料結構
course_info = {
    "課程名稱": "Python 程式設計",
    "授課教師": "Tsung-Min Pai",
    "學分數": 3,
    "上課時間": {
        "星期": "二",
        "節次": ["2", "3", "4"]
    },
    "學生名單": [
        {"姓名": "張同學", "學號": "B10901001", "出席率": 0.95},
        {"姓名": "李同學", "學號": "B10901002", "出席率": 0.88},
        {"姓名": "王同學", "學號": "B10901003", "出席率": 0.92}
    ]
}

# TODO: 使用一般的 print() 輸出資料（觀察效果）
print("=== 一般 print() 輸出 ===")


print("\n" + "="*50 + "\n")

# TODO: 使用 json.dumps() 進行格式化輸出
# 記得使用 ensure_ascii=False 和 indent=2 參數
print("=== JSON 格式化輸出 ===")


# 觀察兩種輸出方式的差異！

# %% [markdown]
# ## 練習 9：錯誤修正練習
#
# **目標：** 學會找出並修正常見的 print() 錯誤

# %%
# 練習 9：錯誤修正
# 以下程式碼包含多個錯誤，請找出並修正它們

name = "小明"
age = 20
height = 175.5

# 錯誤 1：引號不匹配
# TODO: 修正下面這行程式碼
# print("Hello World')


# 錯誤 2：類型錯誤 - 無法直接串接字串和數字
# TODO: 修正下面這行程式碼（有多種修正方法，請選擇一種）
# print("我是" + name + "，今年" + age + "歲")


# 錯誤 3：忘記括號
# TODO: 修正下面這行程式碼
# print "身高:", height


# 錯誤 4：跳脫字元使用錯誤
# TODO: 修正下面這行程式碼，正確顯示引號
# print("他說："今天天氣很好"")


print("\n=== 修正完成後的正確輸出 ===")
# 在這裡重新寫出修正後的程式碼

# %% [markdown]
# ## 練習 10：綜合應用
#
# **目標：** 整合前面學到的所有技巧，建立一個完整的資訊展示程式

# %%
# 練習 10：建立個人資訊展示系統
# 整合使用變數、f-string、print() 參數、格式化等技巧

# TODO: 建立個人基本資料變數
student_name = 
student_id = 
major = 
year = 
gpa = 

# TODO: 建立課程資料（至少 3 門課程及成績）
courses = [
    # {"name": "課程名稱", "credit": 學分數, "grade": 成績}
]

# TODO: 設計並輸出個人資訊展示頁面
# 要求包含以下元素：
# 1. 標題橫幅
# 2. 基本資料（使用 f-string）
# 3. 課程成績表格（對齊格式）
# 4. GPA 顯示（保留 2 位小數）
# 5. 分隔線美化

# 開始你的設計：


# 預期輸出範例：
# ================================================
#               學生資訊系統
# ================================================
# 姓名：張小明
# 學號：B10901001
# 科系：電機工程學系
# 年級：大二
# ------------------------------------------------
# 課程名稱            學分    成績
# ================================================
# 微積分              4       92
# 程式設計            3       88
# 英文                2       85
# ------------------------------------------------
# 總 GPA：3.75
# ================================================

# %% [markdown]
# ## 🎉 恭喜完成練習！
#
# 如果你完成了以上所有練習，恭喜你已經掌握了：
#
# ✅ **基本變數操作**
# ✅ **print() 函式的各種用法**
# ✅ **f-string 字串格式化**
# ✅ **數字格式化技巧**
# ✅ **多行字串和註解**
# ✅ **表格式輸出**
# ✅ **JSON 格式化**
# ✅ **常見錯誤的修正**
#
# ### 📚 下一步學習建議：
# 1. 嘗試修改練習中的範例，加入更多創意
# 2. 練習使用 rich 函式庫（需要先安裝：`pip install rich`）
# 3. 開始學習 input() 函式，建立互動式程式
# 4. 進入下一章：資料型態深入探討
#
# ### 💡 學習提醒：
# - 程式設計需要大量練習，多寫多練是關鍵
# - 遇到錯誤不要慌張，學會讀懂錯誤訊息
# - 善用註解說明你的程式碼
# - 保持程式碼的整潔和可讀性
#
# **繼續加油！🚀**
